# %% [markdown]
# # Day 03. 연산자
#
# 이 노트북은 `curricula/python/basics/30days/day03_연산자.yaml` YAML을 원본으로 생성했습니다. 위에서 아래로 읽고 실행하되, 연습 셀은 일부러 비워둔 공간입니다.
#
# ## 오늘의 목표
#
# 산술, 비교, 논리, 포함 여부 연산자로 값을 계산하고 판단합니다.
#
# ## 왜 중요한가
#
# 연산자는 프로그램이 값을 바꾸고 조건을 판단하는 가장 작은 단위입니다.
#
# ## 생각 모델
#
# 연산자는 두 값 사이에 놓인 질문 또는 계산 기호입니다. 결과는 숫자이거나 참/거짓입니다.
#
# ## 오늘 배우는 것
#
# - 산술 연산자로 수학 계산하기
# - 비교 연산자로 값 비교하기
# - 논리 연산자로 조건 조합하기
# - 멤버십 연산자로 포함 여부 확인하기
#
# ## 학습 방법
#
# 1. 설명을 먼저 읽습니다.
# 2. 바로 아래 코드 셀을 실행합니다.
# 3. 출력이 설명과 어떻게 연결되는지 한 문장으로 말합니다.
# 4. 연습 셀에는 예제를 보지 않고 직접 다시 작성합니다.

# %% [markdown]
# ## 오늘의 범위
#
# - 오늘 새로 배우는 개념: 산술 연산자, 비교 연산자, 논리 연산자, 포함 여부 연산자
# - 이미 써도 되는 개념: 변수, 정수(int), 실수(float), 문자열(str), 참/거짓(bool), type() 타입 확인, print() 출력
# - 오늘은 일부러 쓰지 않는 개념: 리스트, 딕셔너리, 직접 만드는 함수, import
#
# 범위를 좁히는 이유는 간단합니다. 처음 배우는 사람은 한 번에 많은 문법을 보면 어디서 막혔는지 찾기 어렵습니다.

# %% [markdown]
# ## 오늘의 학습 전략
#
# - 코딩 전: 각 줄의 결과가 숫자인지 참/거짓인지 먼저 구분합니다.
# - 실행 중: 복잡한 식은 괄호 안쪽부터 한 단계씩 결과를 확인합니다.
# - 연습 초점: 같은 값을 여러 연산자로 비교하며 결과의 종류를 확인합니다.
# - 막히면: 예상과 다르면 연산자 하나씩만 바꾸고 다시 실행합니다.

# %% [markdown]
# ## 덧셈 연산자
#
# *+ 기호로 더하기*

# %% [markdown]
# ## 뺄셈 연산자
#
# *- 기호로 빼기*

# %% [markdown]
# ## 곱셈 연산자
#
# ** 기호로 곱하기*

# %% [markdown]
# ## 나눗셈 연산자
#
# */ 기호로 나누기*

# %% [markdown]
# ## 몫 연산자
#
# *// 기호로 몫 구하기*

# %% [markdown]
# ## 나머지 연산자
#
# *% 기호로 나머지 구하기*

# %% [markdown]
# ## 거듭제곱 연산자
#
# *** 기호로 제곱 계산*

# %% [markdown]
# ## 같음 비교 연산자
#
# *== 기호로 같은지 확인*

# %% [markdown]
# ## 다름 비교 연산자
#
# *!= 기호로 다른지 확인*

# %% [markdown]
# ## 크기 비교 연산자
#
# *> < >= <= 기호로 크기 비교*

# %% [markdown]
# ## and 논리 연산자
#
# *모두 참이어야 참*

# %% [markdown]
# ## or 논리 연산자
#
# *하나만 참이어도 참*

# %% [markdown]
# ## not 논리 연산자
#
# *참과 거짓 반전*

# %% [markdown]
# ## in 멤버십 연산자
#
# *포함 여부 확인*

# %% [markdown]
# ## 복합 대입 연산자
#
# *연산과 대입을 한번에*

# %% [markdown]
# ## 연산자 우선순위
#
# *계산 순서 이해하기*

# %% [markdown]
# ## 검증 루프: 주문 계산식과 승인 조건
#
# *예측 → 실행 → 오류 수정 → 검증*

# %% [markdown]
# ## Day 3 종합 복습
#
# *연산자 마스터하기*

# %% [markdown]
# ## 완료 기준
#
# - +, -, *, /, //, %, **의 결과 차이를 예로 말할 수 있다.
# - 비교 연산의 결과가 bool이라는 점을 설명할 수 있다.
# - and, or, not을 작은 조건으로 사용할 수 있다.
#
# ## 흔한 막힘
#
# - =와 ==를 혼동함
# - 문자열과 숫자를 함께 계산하려 함
# - and와 or의 결과를 감으로만 판단함
#
# ## 마무리
#
# 오늘 노트북에서 직접 작성한 연습 셀을 다시 훑어보세요. 설명을 보지 않고 같은 코드를 한 번 더 쓸 수 있으면 다음 Day로 넘어갑니다.
