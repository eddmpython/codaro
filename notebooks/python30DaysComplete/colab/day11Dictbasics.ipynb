# %% [markdown]
# # Day 11. 딕셔너리기초
#
# 이 노트북은 `curricula/python/basics/30days/day11_딕셔너리기초.yaml` YAML을 원본으로 생성했습니다. 위에서 아래로 읽고 실행하되, 연습 셀은 일부러 비워둔 공간입니다.
#
# ## 오늘의 목표
#
# 딕셔너리로 키와 값을 묶고, 키로 값을 읽고 바꿉니다.
#
# ## 왜 중요한가
#
# 현실 데이터는 이름:값 구조가 많습니다. 딕셔너리는 그런 데이터를 가장 직접적으로 표현합니다.
#
# ## 생각 모델
#
# 딕셔너리는 이름표가 붙은 서랍입니다. 위치 번호가 아니라 키로 값을 찾습니다.
#
# ## 오늘 배우는 것
#
# - 키-값 쌍으로 데이터 저장
# - 키로 빠르게 값에 접근
# - 딕셔너리 생성과 수정
# - 실전 데이터 구조 활용
#
# ## 학습 방법
#
# 1. 설명을 먼저 읽습니다.
# 2. 바로 아래 코드 셀을 실행합니다.
# 3. 출력이 설명과 어떻게 연결되는지 한 문장으로 말합니다.
# 4. 연습 셀에는 예제를 보지 않고 직접 다시 작성합니다.

# %% [markdown]
# ## 오늘의 범위
#
# - 오늘 새로 배우는 개념: 딕셔너리, 키와 값, 딕셔너리 만들기, 딕셔너리 값 읽기, 딕셔너리 값 바꾸기
# - 이미 써도 되는 개념: 리스트 전체, 튜플, 집합
# - 오늘은 일부러 쓰지 않는 개념: 딕셔너리 메서드, 직접 만드는 함수, import
#
# 범위를 좁히는 이유는 간단합니다. 처음 배우는 사람은 한 번에 많은 문법을 보면 어디서 막혔는지 찾기 어렵습니다.

# %% [markdown]
# ## 오늘의 학습 전략
#
# - 코딩 전: 각 항목에서 콜론 왼쪽 키와 오른쪽 값을 분리해서 읽습니다.
# - 실행 중: 없는 키를 읽을 때와 새 키에 값을 넣을 때의 차이를 확인합니다.
# - 연습 초점: 학생, 상품, 설정처럼 속성이 있는 대상을 딕셔너리로 표현합니다.
# - 막히면: KeyError가 나면 실제 존재하는 키 목록을 먼저 출력합니다.

# %% [markdown]
# ## 딕셔너리란?
#
# *키로 찾는 데이터 저장소*

# %% [markdown]
# ## 딕셔너리 생성하기
#
# *다양한 방법으로 만들기*

# %% [markdown]
# ## 키로 값 접근하기
#
# *대괄호 [] 사용*

# %% [markdown]
# ## 키로 값 수정하기
#
# *기존 값 변경*

# %% [markdown]
# ## 새 키-값 쌍 추가하기
#
# *없는 키에 값 할당*

# %% [markdown]
# ## del로 키-값 삭제
#
# *항목 제거하기*

# %% [markdown]
# ## in/not in 연산자
#
# *키 존재 확인*

# %% [markdown]
# ## 딕셔너리 길이
#
# *len() 함수*

# %% [markdown]
# ## 여러 키-값 접근
#
# *한 번에 여러 값 가져오기*

# %% [markdown]
# ## 중첩 딕셔너리
#
# *딕셔너리 안의 딕셔너리*

# %% [markdown]
# ## 다양한 키 타입
#
# *문자열, 숫자, 튜플*

# %% [markdown]
# ## 검증 루프: 주문 레코드 만들고 필수 필드 확인
#
# *딕셔너리를 업무 데이터의 작은 레코드로 사용하기*

# %% [markdown]
# ## Day 11 종합 복습
#
# *딕셔너리 기초 마스터하기*

# %% [markdown]
# ## 완료 기준
#
# - 딕셔너리를 만들고 키로 값을 읽을 수 있다.
# - 새 키를 추가하고 기존 값을 바꿀 수 있다.
# - 리스트 인덱스와 딕셔너리 키의 차이를 설명할 수 있다.
#
# ## 흔한 막힘
#
# - 키 문자열의 따옴표를 빠뜨림
# - 인덱스처럼 숫자 위치로 접근하려 함
# - 없는 키를 바로 읽음
#
# ## 마무리
#
# 오늘 노트북에서 직접 작성한 연습 셀을 다시 훑어보세요. 설명을 보지 않고 같은 코드를 한 번 더 쓸 수 있으면 다음 Day로 넘어갑니다.
