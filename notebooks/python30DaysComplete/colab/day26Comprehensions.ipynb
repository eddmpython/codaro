# %% [markdown]
# # Day 26. 컴프리헨션
#
# 이 노트북은 `curricula/python/basics/30days/day26_컴프리헨션.yaml` YAML을 원본으로 생성했습니다. 위에서 아래로 읽고 실행하되, 연습 셀은 일부러 비워둔 공간입니다.
#
# ## 오늘의 목표
#
# 리스트, 딕셔너리, 집합 컴프리헨션으로 반복과 조건을 짧게 표현합니다.
#
# ## 왜 중요한가
#
# 컴프리헨션은 데이터 변환 코드를 간결하게 만들지만, 읽을 수 있을 때만 강력합니다.
#
# ## 생각 모델
#
# 컴프리헨션은 반복문을 한 줄 안에 접은 형태입니다. 앞에는 만들 값, 뒤에는 반복과 조건이 옵니다.
#
# ## 오늘 배우는 것
#
# - 리스트 컴프리헨션으로 간결한 코드
# - 딕셔너리 컴프리헨션으로 변환
# - 집합 컴프리헨션으로 중복 제거
# - 중첩 컴프리헨션으로 다차원 처리
#
# ## 학습 방법
#
# 1. 설명을 먼저 읽습니다.
# 2. 바로 아래 코드 셀을 실행합니다.
# 3. 출력이 설명과 어떻게 연결되는지 한 문장으로 말합니다.
# 4. 연습 셀에는 예제를 보지 않고 직접 다시 작성합니다.

# %% [markdown]
# ## 오늘의 범위
#
# - 오늘 새로 배우는 개념: 리스트 컴프리헨션, 딕셔너리 컴프리헨션, 집합 컴프리헨션, 중첩 컴프리헨션
# - 이미 써도 되는 개념: 기본 문법 전체, 반복문, 조건문
# - 오늘은 일부러 쓰지 않는 개념: 제너레이터 표현식, 외부 라이브러리
#
# 범위를 좁히는 이유는 간단합니다. 처음 배우는 사람은 한 번에 많은 문법을 보면 어디서 막혔는지 찾기 어렵습니다.

# %% [markdown]
# ## 오늘의 학습 전략
#
# - 코딩 전: 먼저 일반 for문으로 풀어쓴 모습을 떠올린 뒤 한 줄로 접습니다.
# - 실행 중: 조건이 있는 경우 필터링되는 값과 변환되는 값을 구분합니다.
# - 연습 초점: 숫자 목록 변환, 조건 필터링, 키-값 변환을 각각 컴프리헨션으로 작성합니다.
# - 막히면: 읽기 어려우면 즉시 일반 반복문으로 풀어 써서 확인합니다.

# %% [markdown]
# ## 리스트 컴프리헨션 기초
#
# *간결한 리스트 생성*

# %% [markdown]
# ## 조건부 컴프리헨션
#
# *필터링과 조건문*

# %% [markdown]
# ## 고급 리스트 컴프리헨션
#
# *복잡한 표현식과 다중 조건*

# %% [markdown]
# ## 딕셔너리 컴프리헨션
#
# *딕셔너리 생성과 변환*

# %% [markdown]
# ## 집합 컴프리헨션
#
# *중복 없는 집합 생성*

# %% [markdown]
# ## 중첩 컴프리헨션
#
# *다차원 데이터 처리*

# %% [markdown]
# ## 컴프리헨션 실전
#
# *실용적인 활용 패턴*

# %% [markdown]
# ## 현업 흐름 검증: 주문 행을 컴프리헨션으로 정제하기
#
# *예측 → 변환 → 필터링 → 오류 확인 → 검증*

# %% [markdown]
# ## Day 26 종합 복습
#
# *컴프리헨션 마스터하기*

# %% [markdown]
# ## 완료 기준
#
# - 리스트 컴프리헨션을 일반 for문으로 풀어 설명할 수 있다.
# - 조건이 있는 컴프리헨션을 사용할 수 있다.
# - 딕셔너리와 집합 컴프리헨션의 결과 모양을 구분할 수 있다.
#
# ## 흔한 막힘
#
# - 만들 값과 반복 대상을 거꾸로 씀
# - 조건 위치를 헷갈림
# - 중첩 컴프리헨션을 지나치게 복잡하게 만듦
#
# ## 마무리
#
# 오늘 노트북에서 직접 작성한 연습 셀을 다시 훑어보세요. 설명을 보지 않고 같은 코드를 한 번 더 쓸 수 있으면 다음 Day로 넘어갑니다.
