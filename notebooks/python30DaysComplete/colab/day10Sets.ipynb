# %% [markdown]
# # Day 10. 집합
#
# 이 노트북은 `curricula/python/basics/30days/day10_집합.yaml` YAML을 원본으로 생성했습니다. 위에서 아래로 읽고 실행하되, 연습 셀은 일부러 비워둔 공간입니다.
#
# ## 오늘의 목표
#
# 집합으로 중복을 제거하고 합집합, 교집합, 차집합을 계산합니다.
#
# ## 왜 중요한가
#
# 중복 제거와 공통 항목 찾기는 데이터 정리에서 자주 등장하는 문제입니다.
#
# ## 생각 모델
#
# 집합은 순서보다 포함 여부가 중요한 값 묶음입니다. 같은 값은 한 번만 남습니다.
#
# ## 오늘 배우는 것
#
# - 집합으로 중복 없는 데이터 관리
# - add/remove로 요소 추가/삭제
# - 합집합, 교집합, 차집합 연산
# - 수학의 집합 개념을 프로그래밍에
#
# ## 학습 방법
#
# 1. 설명을 먼저 읽습니다.
# 2. 바로 아래 코드 셀을 실행합니다.
# 3. 출력이 설명과 어떻게 연결되는지 한 문장으로 말합니다.
# 4. 연습 셀에는 예제를 보지 않고 직접 다시 작성합니다.

# %% [markdown]
# ## 오늘의 범위
#
# - 오늘 새로 배우는 개념: 집합, 중복 제거, add(), remove(), discard(), 합집합, 교집합, 차집합
# - 이미 써도 되는 개념: 리스트 전체, 튜플
# - 오늘은 일부러 쓰지 않는 개념: 딕셔너리, 직접 만드는 함수, import
#
# 범위를 좁히는 이유는 간단합니다. 처음 배우는 사람은 한 번에 많은 문법을 보면 어디서 막혔는지 찾기 어렵습니다.

# %% [markdown]
# ## 오늘의 학습 전략
#
# - 코딩 전: 순서를 기대하지 말고 어떤 값이 포함될지만 먼저 봅니다.
# - 실행 중: 리스트를 집합으로 바꿨을 때 중복이 어떻게 줄어드는지 확인합니다.
# - 연습 초점: 두 그룹의 공통 관심사, 한쪽에만 있는 항목을 집합 연산으로 구합니다.
# - 막히면: KeyError가 나면 remove() 대신 discard()가 필요한 상황인지 확인합니다.

# %% [markdown]
# ## 집합이란?
#
# *중복 없고 순서 없는 자료구조*

# %% [markdown]
# ## 집합 생성하기
#
# *다양한 방법으로 만들기*

# %% [markdown]
# ## 중복 제거 특성
#
# *자동으로 중복 삭제*

# %% [markdown]
# ## add() 메서드
#
# *집합에 요소 추가*

# %% [markdown]
# ## remove()와 discard()
#
# *집합에서 요소 삭제*

# %% [markdown]
# ## clear() 메서드
#
# *모든 요소 삭제*

# %% [markdown]
# ## 합집합 (union)
#
# *두 집합을 합치기*

# %% [markdown]
# ## 교집합 (intersection)
#
# *공통 요소만 추출*

# %% [markdown]
# ## 차집합 (difference)
#
# *한쪽에만 있는 요소*

# %% [markdown]
# ## 대칭차집합 (symmetric_difference)
#
# *한쪽에만 있는 모든 요소*

# %% [markdown]
# ## in/not in 연산자
#
# *요소 포함 확인*

# %% [markdown]
# ## 집합 길이
#
# *len() 함수*

# %% [markdown]
# ## 검증 루프: 권한과 참석자 집합 비교하기
#
# *중복 제거와 집합 연산을 운영 점검에 사용*

# %% [markdown]
# ## Day 10 종합 복습
#
# *집합 마스터하기*

# %% [markdown]
# ## 완료 기준
#
# - set()으로 중복을 제거할 수 있다.
# - 합집합, 교집합, 차집합을 예로 설명할 수 있다.
# - add(), remove(), discard()의 차이를 말할 수 있다.
#
# ## 흔한 막힘
#
# - 집합에 순서가 있다고 기대함
# - 빈 집합을 {}로 만들려 함
# - remove()와 discard()의 실패 동작을 혼동함
#
# ## 마무리
#
# 오늘 노트북에서 직접 작성한 연습 셀을 다시 훑어보세요. 설명을 보지 않고 같은 코드를 한 번 더 쓸 수 있으면 다음 Day로 넘어갑니다.
