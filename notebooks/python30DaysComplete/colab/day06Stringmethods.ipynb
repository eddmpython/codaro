# %% [markdown]
# # Day 06. 문자열 메서드
#
# 이 노트북은 `curricula/python/basics/30days/day06_문자열메서드.yaml` YAML을 원본으로 생성했습니다. 위에서 아래로 읽고 실행하되, 연습 셀은 일부러 비워둔 공간입니다.
#
# ## 오늘의 목표
#
# 문자열 메서드로 대소문자, 분리, 결합, 치환, 공백 제거, 검색을 처리합니다.
#
# ## 왜 중요한가
#
# 현실의 텍스트 데이터는 공백, 대소문자, 구분자가 섞여 있어 정리 과정이 필요합니다.
#
# ## 생각 모델
#
# 메서드는 값 뒤에 붙여 쓰는 동작 버튼입니다. 원본 문자열을 읽고 새 결과를 만들어 냅니다.
#
# ## 오늘 배우는 것
#
# - 대소문자 변환 메서드
# - 공백 제거와 문자열 정리
# - 문자열 치환과 검색
# - 문자열 분할과 개수 세기
#
# ## 학습 방법
#
# 1. 설명을 먼저 읽습니다.
# 2. 바로 아래 코드 셀을 실행합니다.
# 3. 출력이 설명과 어떻게 연결되는지 한 문장으로 말합니다.
# 4. 연습 셀에는 예제를 보지 않고 직접 다시 작성합니다.

# %% [markdown]
# ## 오늘의 범위
#
# - 오늘 새로 배우는 개념: upper(), lower(), split(), join(), replace(), strip(), find(), count()
# - 이미 써도 되는 개념: 문자열 기초, 인덱싱, 슬라이싱
# - 오늘은 일부러 쓰지 않는 개념: 리스트 메서드, 직접 만드는 함수, import
#
# 범위를 좁히는 이유는 간단합니다. 처음 배우는 사람은 한 번에 많은 문법을 보면 어디서 막혔는지 찾기 어렵습니다.

# %% [markdown]
# ## 오늘의 학습 전략
#
# - 코딩 전: 점 앞의 값이 무엇이고 점 뒤의 동작이 무엇인지 나누어 읽습니다.
# - 실행 중: 메서드 실행 후 원본 변수와 결과 값을 따로 확인합니다.
# - 연습 초점: 문장을 단어로 나누고 다시 합치며 split()과 join()의 짝을 익힙니다.
# - 막히면: AttributeError가 나면 점 앞의 값이 문자열인지 확인합니다.

# %% [markdown]
# ## 대문자 변환
#
# *upper()로 모두 대문자로*

# %% [markdown]
# ## 소문자 변환
#
# *lower()로 모두 소문자로*

# %% [markdown]
# ## 첫 글자 대문자
#
# *capitalize()로 첫 문자만 대문자*

# %% [markdown]
# ## 제목 형식
#
# *title()로 각 단어 첫 글자 대문자*

# %% [markdown]
# ## 양쪽 공백 제거
#
# *strip()으로 공백 정리*

# %% [markdown]
# ## 한쪽 공백 제거
#
# *lstrip(), rstrip()으로 한쪽만 제거*

# %% [markdown]
# ## 문자열 치환
#
# *replace()로 문자 바꾸기*

# %% [markdown]
# ## 여러 개 치환
#
# *모든 일치 항목 바꾸기*

# %% [markdown]
# ## 문자열 나누기
#
# *split()으로 구분자 기준 분리*

# %% [markdown]
# ## 문자열 합치기
#
# *join()으로 리스트를 문자열로 조립*

# %% [markdown]
# ## 문자열 개수 세기
#
# *count()로 등장 횟수 확인*

# %% [markdown]
# ## 문자열 위치 찾기
#
# *find()로 첫 등장 위치 확인*

# %% [markdown]
# ## 찾기 실패
#
# *없는 문자 찾을 때*

# %% [markdown]
# ## 시작 문자 확인
#
# *startswith()로 시작 여부 확인*

# %% [markdown]
# ## 끝 문자 확인
#
# *endswith()로 종료 여부 확인*

# %% [markdown]
# ## 검증 루프: 고객 행 정제하기
#
# *공백, 대소문자, 쉼표 형식을 업무 데이터로 정리*

# %% [markdown]
# ## Day 6 종합 복습
#
# *문자열 메서드 마스터하기*

# %% [markdown]
# ## 완료 기준
#
# - split()으로 문자열을 나누고 join()으로 다시 합칠 수 있다.
# - replace(), strip(), find(), count()의 쓰임을 예로 설명할 수 있다.
# - 문자열 메서드가 새 값을 만든다는 점을 말할 수 있다.
#
# ## 흔한 막힘
#
# - join()을 구분자가 아니라 리스트 뒤에 붙여 씀
# - find()가 못 찾을 때 -1을 준다는 점을 놓침
# - 메서드 결과를 변수에 다시 담지 않음
#
# ## 마무리
#
# 오늘 노트북에서 직접 작성한 연습 셀을 다시 훑어보세요. 설명을 보지 않고 같은 코드를 한 번 더 쓸 수 있으면 다음 Day로 넘어갑니다.
