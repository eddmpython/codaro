# %% [markdown]
# # Day 19. 파일입출력
#
# 이 노트북은 `curricula/python/basics/30days/day19_파일입출력.yaml` YAML을 원본으로 생성했습니다. 위에서 아래로 읽고 실행하되, 연습 셀은 일부러 비워둔 공간입니다.
#
# ## 오늘의 목표
#
# open(), read(), write(), with로 파일을 읽고 씁니다.
#
# ## 왜 중요한가
#
# 프로그램이 끝난 뒤에도 데이터를 남기려면 파일 입출력이 필요합니다.
#
# ## 생각 모델
#
# 파일은 프로그램 밖에 있는 노트입니다. with는 노트를 열고 작업한 뒤 안전하게 닫아주는 틀입니다.
#
# ## 오늘 배우는 것
#
# - 파일 열기와 닫기
# - 파일 읽고 쓰기
# - with문으로 안전하게
# - 파일 모드 이해
#
# ## 학습 방법
#
# 1. 설명을 먼저 읽습니다.
# 2. 바로 아래 코드 셀을 실행합니다.
# 3. 출력이 설명과 어떻게 연결되는지 한 문장으로 말합니다.
# 4. 연습 셀에는 예제를 보지 않고 직접 다시 작성합니다.

# %% [markdown]
# ## 오늘의 범위
#
# - 오늘 새로 배우는 개념: open(), read(), write(), with, close(), 파일 모드
# - 이미 써도 되는 개념: 함수 전체, import
# - 오늘은 일부러 쓰지 않는 개념: 클래스, 외부 라이브러리
#
# 범위를 좁히는 이유는 간단합니다. 처음 배우는 사람은 한 번에 많은 문법을 보면 어디서 막혔는지 찾기 어렵습니다.

# %% [markdown]
# ## 오늘의 학습 전략
#
# - 코딩 전: 읽기 모드인지 쓰기 모드인지, 파일 이름이 무엇인지 먼저 확인합니다.
# - 실행 중: 파일에 쓴 뒤 다시 읽어 실제 내용이 저장됐는지 확인합니다.
# - 연습 초점: 짧은 메모를 파일로 저장하고 다시 읽어 출력합니다.
# - 막히면: FileNotFoundError가 나면 현재 작업 폴더와 파일 이름 철자를 확인합니다.

# %% [markdown]
# ## 파일 열기
#
# *open() 함수*

# %% [markdown]
# ## 파일 읽기
#
# *read() 메서드*

# %% [markdown]
# ## 파일 쓰기
#
# *write() 메서드*

# %% [markdown]
# ## with 문
#
# *자동으로 닫기*

# %% [markdown]
# ## 파일 모드
#
# *읽기/쓰기/추가*

# %% [markdown]
# ## 줄 단위 순회
#
# *for문으로 읽기*

# %% [markdown]
# ## 검증 루프: 임시 작업 폴더에서 리포트 파일 만들기
#
# *로컬 파일을 안전하게 쓰고 읽고 검증하기*

# %% [markdown]
# ## Day 19 종합 복습
#
# *파일 입출력 마스터하기*

# %% [markdown]
# ## 완료 기준
#
# - with open(...) 구조로 파일을 안전하게 다룰 수 있다.
# - 읽기 모드와 쓰기 모드의 차이를 설명할 수 있다.
# - write()로 저장한 내용을 read()로 다시 확인할 수 있다.
#
# ## 흔한 막힘
#
# - 쓰기 모드가 기존 내용을 덮어쓴다는 점을 놓침
# - 파일을 닫기 전에 읽으려 함
# - 실행 위치와 파일 위치를 혼동함
#
# ## 마무리
#
# 오늘 노트북에서 직접 작성한 연습 셀을 다시 훑어보세요. 설명을 보지 않고 같은 코드를 한 번 더 쓸 수 있으면 다음 Day로 넘어갑니다.
