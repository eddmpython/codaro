# %% [markdown]
# # Day 29. 알고리즘 연습
#
# 이 노트북은 `curricula/python/basics/30days/day29_알고리즘연습.yaml` YAML을 원본으로 생성했습니다. 위에서 아래로 읽고 실행하되, 연습 셀은 일부러 비워둔 공간입니다.
#
# ## 오늘의 목표
#
# 정렬, 탐색, 재귀 문제를 작은 단계로 나누어 해결합니다.
#
# ## 왜 중요한가
#
# 알고리즘 연습은 문법을 문제 해결 절차로 바꾸는 훈련입니다.
#
# ## 생각 모델
#
# 알고리즘은 정답 코드가 아니라 입력을 출력으로 바꾸는 단계 목록입니다.
#
# ## 오늘 배우는 것
#
# - 정렬 알고리즘 구현
# - 검색 알고리즘 마스터
# - 재귀 함수 활용
# - 문제 해결 능력 향상
#
# ## 학습 방법
#
# 1. 설명을 먼저 읽습니다.
# 2. 바로 아래 코드 셀을 실행합니다.
# 3. 출력이 설명과 어떻게 연결되는지 한 문장으로 말합니다.
# 4. 연습 셀에는 예제를 보지 않고 직접 다시 작성합니다.

# %% [markdown]
# ## 오늘의 범위
#
# - 오늘 새로 배우는 개념: 정렬, 탐색, 재귀
# - 이미 써도 되는 개념: 전체 문법
# - 오늘은 일부러 쓰지 않는 개념: 외부 라이브러리
#
# 범위를 좁히는 이유는 간단합니다. 처음 배우는 사람은 한 번에 많은 문법을 보면 어디서 막혔는지 찾기 어렵습니다.

# %% [markdown]
# ## 오늘의 학습 전략
#
# - 코딩 전: 입력 예시, 원하는 출력, 직접 손으로 푸는 절차를 먼저 적습니다.
# - 실행 중: 작은 입력부터 실행하고 중간 값을 출력해 절차가 맞는지 확인합니다.
# - 연습 초점: 정렬 기준 바꾸기, 원하는 값 찾기, 재귀의 종료 조건을 집중 연습합니다.
# - 막히면: 재귀가 끝나지 않으면 종료 조건과 더 작은 문제로 줄어드는 줄을 확인합니다.

# %% [markdown]
# ## 정렬 알고리즘
#
# *데이터 정렬하기*

# %% [markdown]
# ## 검색 알고리즘
#
# *데이터 찾기*

# %% [markdown]
# ## 재귀 함수 기초
#
# *함수가 자기 자신을 호출*

# %% [markdown]
# ## 재귀 심화
#
# *복잡한 재귀 문제*

# %% [markdown]
# ## 알고리즘 패턴
#
# *자주 사용되는 패턴*

# %% [markdown]
# ## 실전 문제
#
# *종합 알고리즘 문제*

# %% [markdown]
# ## 현업 흐름 검증: 알고리즘 전제를 확인하고 선택하기
#
# *예측 → 전제 검증 → 구현 → 경계값 테스트*

# %% [markdown]
# ## Day 29 종합 복습
#
# *알고리즘 마스터하기*

# %% [markdown]
# ## 완료 기준
#
# - 문제를 입력, 처리, 출력으로 나눌 수 있다.
# - 정렬과 탐색의 기본 절차를 설명할 수 있다.
# - 재귀 함수의 종료 조건과 재귀 호출을 구분할 수 있다.
#
# ## 흔한 막힘
#
# - 문제 이해 전에 코드부터 씀
# - 중간 값을 확인하지 않음
# - 재귀 종료 조건을 빠뜨림
#
# ## 마무리
#
# 오늘 노트북에서 직접 작성한 연습 셀을 다시 훑어보세요. 설명을 보지 않고 같은 코드를 한 번 더 쓸 수 있으면 다음 Day로 넘어갑니다.
