# %% [markdown]
# # Day 17. 스코프와클로저
#
# 이 노트북은 `curricula/python/basics/30days/day17_스코프와클로저.yaml` YAML을 원본으로 생성했습니다. 위에서 아래로 읽고 실행하되, 연습 셀은 일부러 비워둔 공간입니다.
#
# ## 오늘의 목표
#
# 스코프, global, nonlocal, 클로저로 이름이 보이는 범위를 이해합니다.
#
# ## 왜 중요한가
#
# 함수가 많아질수록 값이 어디서 왔고 어디까지 영향을 주는지 알아야 오류를 줄일 수 있습니다.
#
# ## 생각 모델
#
# 스코프는 이름을 찾는 방입니다. 파이썬은 현재 방에서 찾고, 없으면 바깥 방을 확인합니다.
#
# ## 오늘 배우는 것
#
# - 변수 스코프 이해
# - global과 nonlocal
# - 클로저로 상태 보존
# - 고급 함수 패턴
#
# ## 학습 방법
#
# 1. 설명을 먼저 읽습니다.
# 2. 바로 아래 코드 셀을 실행합니다.
# 3. 출력이 설명과 어떻게 연결되는지 한 문장으로 말합니다.
# 4. 연습 셀에는 예제를 보지 않고 직접 다시 작성합니다.

# %% [markdown]
# ## 오늘의 범위
#
# - 오늘 새로 배우는 개념: global, nonlocal, 클로저, 스코프
# - 이미 써도 되는 개념: 함수 전체
# - 오늘은 일부러 쓰지 않는 개념: import, 클래스
#
# 범위를 좁히는 이유는 간단합니다. 처음 배우는 사람은 한 번에 많은 문법을 보면 어디서 막혔는지 찾기 어렵습니다.

# %% [markdown]
# ## 오늘의 학습 전략
#
# - 코딩 전: 각 변수 이름이 함수 안에서 만들어졌는지 밖에서 만들어졌는지 표시합니다.
# - 실행 중: 같은 이름이 안과 밖에 있을 때 어느 값이 출력되는지 확인합니다.
# - 연습 초점: 전역 변수를 직접 바꾸기보다 함수가 값을 받아 돌려주는 구조를 우선 사용합니다.
# - 막히면: UnboundLocalError가 나면 함수 안에서 같은 이름에 대입한 줄이 있는지 확인합니다.

# %% [markdown]
# ## 지역 변수
#
# *함수 내부 변수*

# %% [markdown]
# ## 전역 변수
#
# *함수 외부 변수*

# %% [markdown]
# ## global 키워드
#
# *전역 변수 수정*

# %% [markdown]
# ## 중첩 함수
#
# *함수 안의 함수*

# %% [markdown]
# ## nonlocal 키워드
#
# *외부 함수 변수 수정*

# %% [markdown]
# ## 클로저 기본
#
# *상태를 기억하는 함수*

# %% [markdown]
# ## 클로저 활용
#
# *상태를 가진 함수*

# %% [markdown]
# ## 검증 루프: 고객별 누적 결제 상태 만들기
#
# *global 대신 클로저로 상태를 격리하고 검증*

# %% [markdown]
# ## Day 17 종합 복습
#
# *스코프와 클로저 마스터하기*

# %% [markdown]
# ## 완료 기준
#
# - 지역 스코프와 전역 스코프를 구분할 수 있다.
# - global과 nonlocal이 필요한 상황을 예로 설명할 수 있다.
# - 클로저가 바깥 함수의 값을 기억한다는 점을 말할 수 있다.
#
# ## 흔한 막힘
#
# - 함수 안 대입이 바깥 변수도 자동으로 바꾼다고 생각함
# - global을 습관적으로 사용함
# - 클로저의 기억되는 값을 출력 결과만으로 외움
#
# ## 마무리
#
# 오늘 노트북에서 직접 작성한 연습 셀을 다시 훑어보세요. 설명을 보지 않고 같은 코드를 한 번 더 쓸 수 있으면 다음 Day로 넘어갑니다.
