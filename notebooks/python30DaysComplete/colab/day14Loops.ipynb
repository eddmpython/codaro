# %% [markdown]
# # Day 14. 반복문
#
# 이 노트북은 `curricula/python/basics/30days/day14_반복문.yaml` YAML을 원본으로 생성했습니다. 위에서 아래로 읽고 실행하되, 연습 셀은 일부러 비워둔 공간입니다.
#
# ## 오늘의 목표
#
# for, while, range(), break, continue로 반복 실행을 제어합니다.
#
# ## 왜 중요한가
#
# 반복문은 같은 일을 사람이 여러 번 쓰지 않도록 만드는 핵심 도구입니다.
#
# ## 생각 모델
#
# for는 정해진 목록을 하나씩 꺼내는 흐름이고, while은 조건이 참인 동안 계속 도는 흐름입니다.
#
# ## 오늘 배우는 것
#
# - for로 컬렉션 순회
# - while로 조건 반복
# - break, continue로 제어
# - 중첩 반복문 활용
#
# ## 학습 방법
#
# 1. 설명을 먼저 읽습니다.
# 2. 바로 아래 코드 셀을 실행합니다.
# 3. 출력이 설명과 어떻게 연결되는지 한 문장으로 말합니다.
# 4. 연습 셀에는 예제를 보지 않고 직접 다시 작성합니다.

# %% [markdown]
# ## 오늘의 범위
#
# - 오늘 새로 배우는 개념: for 반복문, while 반복문, range(), break, continue, 반복문 else, 중첩 반복문
# - 이미 써도 되는 개념: 지금까지 배운 자료형, 조건문
# - 오늘은 일부러 쓰지 않는 개념: 직접 만드는 함수, import
#
# 범위를 좁히는 이유는 간단합니다. 처음 배우는 사람은 한 번에 많은 문법을 보면 어디서 막혔는지 찾기 어렵습니다.

# %% [markdown]
# ## 오늘의 학습 전략
#
# - 코딩 전: 반복 횟수와 반복할 때마다 바뀌는 값을 먼저 표시합니다.
# - 실행 중: 반복문 안과 밖의 출력 위치 차이를 확인합니다.
# - 연습 초점: 리스트의 모든 값 처리, 숫자 범위 누적, 조건에 따른 중단을 연습합니다.
# - 막히면: 무한 반복이 의심되면 while 조건을 바꾸는 줄이 있는지 확인합니다.

# %% [markdown]
# ## for 리스트 순회
#
# *리스트의 모든 요소 처리*

# %% [markdown]
# ## for 문자열 순회
#
# *문자열의 각 문자 처리*

# %% [markdown]
# ## for 딕셔너리 순회
#
# *키, 값, 아이템 순회*

# %% [markdown]
# ## range() 함수
#
# *숫자 시퀀스 생성*

# %% [markdown]
# ## range()와 for
#
# *정해진 횟수만큼 반복*

# %% [markdown]
# ## while 기본
#
# *조건이 참인 동안 반복*

# %% [markdown]
# ## break 문
#
# *반복문 즉시 종료*

# %% [markdown]
# ## continue 문
#
# *현재 반복 건너뛰기*

# %% [markdown]
# ## for-else 절
#
# *정상 종료시 실행*

# %% [markdown]
# ## while-else 절
#
# *조건 거짓시 실행*

# %% [markdown]
# ## 중첩 반복문
#
# *반복문 안의 반복문*

# %% [markdown]
# ## 실무 반복 처리 루프
#
# *예측 → 누적 → 오류 확인 → 검증*

# %% [markdown]
# ## Day 14 종합 복습
#
# *반복문 마스터하기*

# %% [markdown]
# ## 완료 기준
#
# - for와 while을 언제 쓰는지 구분할 수 있다.
# - range()로 반복 횟수를 만들 수 있다.
# - break와 continue의 차이를 예로 설명할 수 있다.
#
# ## 흔한 막힘
#
# - 반복문 안 들여쓰기를 빼먹음
# - while 조건을 바꾸지 않아 끝나지 않음
# - range()의 끝 값이 포함된다고 생각함
#
# ## 마무리
#
# 오늘 노트북에서 직접 작성한 연습 셀을 다시 훑어보세요. 설명을 보지 않고 같은 코드를 한 번 더 쓸 수 있으면 다음 Day로 넘어갑니다.
