# %% [markdown]
# # Day 15. 함수기초
#
# 이 노트북은 `curricula/python/basics/30days/day15_함수기초.yaml` YAML을 원본으로 생성했습니다. 위에서 아래로 읽고 실행하되, 연습 셀은 일부러 비워둔 공간입니다.
#
# ## 오늘의 목표
#
# def, 매개변수, 인자, return으로 코드를 재사용 가능한 함수로 묶습니다.
#
# ## 왜 중요한가
#
# 함수는 같은 로직을 여러 번 쓰게 만들고, 프로그램을 작은 단위로 이해하게 해줍니다.
#
# ## 생각 모델
#
# 함수는 입력을 받아 작업한 뒤 결과를 돌려주는 작은 기계입니다.
#
# ## 오늘 배우는 것
#
# - def로 함수 정의
# - return으로 값 반환
# - 매개변수로 값 전달
# - 함수로 코드 재사용
#
# ## 학습 방법
#
# 1. 설명을 먼저 읽습니다.
# 2. 바로 아래 코드 셀을 실행합니다.
# 3. 출력이 설명과 어떻게 연결되는지 한 문장으로 말합니다.
# 4. 연습 셀에는 예제를 보지 않고 직접 다시 작성합니다.

# %% [markdown]
# ## 오늘의 범위
#
# - 오늘 새로 배우는 개념: def 함수 정의, return, 매개변수, 인자, 문서 문자열
# - 이미 써도 되는 개념: 지금까지 배운 자료형, 조건문, 반복문
# - 오늘은 일부러 쓰지 않는 개념: 고급 함수 문법, import, 클래스
#
# 범위를 좁히는 이유는 간단합니다. 처음 배우는 사람은 한 번에 많은 문법을 보면 어디서 막혔는지 찾기 어렵습니다.

# %% [markdown]
# ## 오늘의 학습 전략
#
# - 코딩 전: 함수 이름, 입력 이름, 돌려줄 값을 먼저 나누어 적습니다.
# - 실행 중: 함수를 정의하는 셀과 호출하는 셀이 다르다는 점을 확인합니다.
# - 연습 초점: 반복해서 쓰던 계산이나 메시지 만들기를 함수로 바꿉니다.
# - 막히면: None이 나오면 return이 있는지, print()만 한 것은 아닌지 확인합니다.

# %% [markdown]
# ## 함수 정의
#
# *def로 함수 만들기*

# %% [markdown]
# ## return 문
#
# *값 반환하기*

# %% [markdown]
# ## 매개변수 1개
#
# *값을 받는 함수*

# %% [markdown]
# ## 매개변수 여러 개
#
# *여러 값 받기*

# %% [markdown]
# ## 여러 값 반환
#
# *튜플로 반환*

# %% [markdown]
# ## 매개변수 없는 함수
#
# *입력 없이 실행*

# %% [markdown]
# ## return 없는 함수
#
# *작업만 수행*

# %% [markdown]
# ## 함수와 조건문
#
# *조건에 따른 처리*

# %% [markdown]
# ## 함수와 반복문
#
# *반복 처리 함수*

# %% [markdown]
# ## 함수 재사용
#
# *같은 함수 여러 번 사용*

# %% [markdown]
# ## 실무 함수 설계 루프
#
# *예측 → 실행 → 오류 수정 → 검증*

# %% [markdown]
# ## Day 15 종합 복습
#
# *함수 기초 마스터하기*

# %% [markdown]
# ## 완료 기준
#
# - 매개변수와 인자의 차이를 설명할 수 있다.
# - return 값이 호출 위치로 돌아온다는 점을 말할 수 있다.
# - docstring으로 함수의 의도를 짧게 남길 수 있다.
#
# ## 흔한 막힘
#
# - 함수를 정의만 하고 호출하지 않음
# - print()와 return을 혼동함
# - 매개변수 이름과 호출 값을 같은 것으로 착각함
#
# ## 마무리
#
# 오늘 노트북에서 직접 작성한 연습 셀을 다시 훑어보세요. 설명을 보지 않고 같은 코드를 한 번 더 쓸 수 있으면 다음 Day로 넘어갑니다.
