# %% [markdown]
# # Day 27. 제너레이터와 이터레이터
#
# 이 노트북은 `curricula/python/basics/30days/day27_제너레이터와이터레이터.yaml` YAML을 원본으로 생성했습니다. 위에서 아래로 읽고 실행하되, 연습 셀은 일부러 비워둔 공간입니다.
#
# ## 오늘의 목표
#
# yield, generator, iter(), next()로 값을 필요할 때 하나씩 만드는 흐름을 이해합니다.
#
# ## 왜 중요한가
#
# 큰 데이터를 한꺼번에 만들지 않고 필요한 만큼만 처리하는 방식은 효율적인 프로그램의 기초입니다.
#
# ## 생각 모델
#
# 제너레이터는 멈췄다가 다음 값을 요청받으면 이어서 실행되는 함수입니다.
#
# ## 오늘 배우는 것
#
# - yield로 제너레이터 생성
# - 메모리 효율적인 순회
# - iter()와 next() 활용
# - 이터레이터 프로토콜 구현
#
# ## 학습 방법
#
# 1. 설명을 먼저 읽습니다.
# 2. 바로 아래 코드 셀을 실행합니다.
# 3. 출력이 설명과 어떻게 연결되는지 한 문장으로 말합니다.
# 4. 연습 셀에는 예제를 보지 않고 직접 다시 작성합니다.

# %% [markdown]
# ## 오늘의 범위
#
# - 오늘 새로 배우는 개념: yield, 제너레이터, iter(), next(), 이터레이터 규약
# - 이미 써도 되는 개념: 함수 전체, 클래스 전체, 컴프리헨션
# - 오늘은 일부러 쓰지 않는 개념: 외부 라이브러리
#
# 범위를 좁히는 이유는 간단합니다. 처음 배우는 사람은 한 번에 많은 문법을 보면 어디서 막혔는지 찾기 어렵습니다.

# %% [markdown]
# ## 오늘의 학습 전략
#
# - 코딩 전: return으로 끝나는 함수와 yield로 잠시 멈추는 함수를 비교합니다.
# - 실행 중: next()를 여러 번 호출하며 함수가 어디서 이어지는지 확인합니다.
# - 연습 초점: 숫자 흐름, 필터링 흐름, 파일 줄 처리처럼 하나씩 꺼내는 예제를 만듭니다.
# - 막히면: StopIteration이 나오면 더 꺼낼 값이 남아 있는지 확인합니다.

# %% [markdown]
# ## 제너레이터 기초
#
# *yield 키워드*

# %% [markdown]
# ## 제너레이터 표현식
#
# *간결한 제너레이터 생성*

# %% [markdown]
# ## 이터레이터 기초
#
# *iter()와 next()*

# %% [markdown]
# ## 이터레이터 프로토콜
#
# *__iter__와 __next__ 구현*

# %% [markdown]
# ## 고급 제너레이터
#
# *실전 활용 패턴*

# %% [markdown]
# ## 실전 패턴
#
# *제너레이터와 이터레이터 활용*

# %% [markdown]
# ## 실무 스트리밍 처리 루프
#
# *예측 → 지연 처리 → 소진 확인 → 검증*

# %% [markdown]
# ## Day 27 종합 복습
#
# *제너레이터와 이터레이터 마스터하기*

# %% [markdown]
# ## 완료 기준
#
# - yield와 return의 차이를 설명할 수 있다.
# - iter()와 next()로 값을 하나씩 꺼낼 수 있다.
# - 이터레이터 규약이 무엇을 약속하는지 말할 수 있다.
#
# ## 흔한 막힘
#
# - 제너레이터를 리스트처럼 바로 값 묶음으로 생각함
# - next() 이후 상태가 이어진다는 점을 놓침
# - StopIteration을 오류로만 해석함
#
# ## 마무리
#
# 오늘 노트북에서 직접 작성한 연습 셀을 다시 훑어보세요. 설명을 보지 않고 같은 코드를 한 번 더 쓸 수 있으면 다음 Day로 넘어갑니다.
