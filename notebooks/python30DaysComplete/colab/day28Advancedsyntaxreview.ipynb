# %% [markdown]
# # Day 28. 고급 문법 종합
#
# 이 노트북은 `curricula/python/basics/30days/day28_고급문법종합.yaml` YAML을 원본으로 생성했습니다. 위에서 아래로 읽고 실행하되, 연습 셀은 일부러 비워둔 공간입니다.
#
# ## 오늘의 목표
#
# 컨텍스트 매니저와 with 문을 직접 만들어 자원 정리 흐름을 이해합니다.
#
# ## 왜 중요한가
#
# 파일, 연결, 임시 상태처럼 열고 닫아야 하는 작업은 안전한 정리 구조가 필요합니다.
#
# ## 생각 모델
#
# with는 시작할 때 준비하고 끝날 때 정리하는 출입문입니다. 컨텍스트 매니저는 그 출입문 규칙을 구현합니다.
#
# ## 오늘 배우는 것
#
# - with 문으로 리소스 관리
# - 컨텍스트 매니저 프로토콜
# - 자동 정리 메커니즘
# - 커스텀 컨텍스트 매니저
#
# ## 학습 방법
#
# 1. 설명을 먼저 읽습니다.
# 2. 바로 아래 코드 셀을 실행합니다.
# 3. 출력이 설명과 어떻게 연결되는지 한 문장으로 말합니다.
# 4. 연습 셀에는 예제를 보지 않고 직접 다시 작성합니다.

# %% [markdown]
# ## 오늘의 범위
#
# - 오늘 새로 배우는 개념: 컨텍스트 매니저, with 문, 직접 만드는 컨텍스트 매니저
# - 이미 써도 되는 개념: 전체 문법
# - 오늘은 일부러 쓰지 않는 개념: 외부 라이브러리
#
# 범위를 좁히는 이유는 간단합니다. 처음 배우는 사람은 한 번에 많은 문법을 보면 어디서 막혔는지 찾기 어렵습니다.

# %% [markdown]
# ## 오늘의 학습 전략
#
# - 코딩 전: 어떤 작업이 시작 준비와 끝 정리를 필요로 하는지 먼저 찾습니다.
# - 실행 중: with 블록 안에서 오류가 나도 정리 코드가 실행되는지 확인합니다.
# - 연습 초점: 간단한 로그 출력 컨텍스트 매니저를 만들고 실행 순서를 관찰합니다.
# - 막히면: 정리가 안 되면 __enter__와 __exit__ 이름과 반환 흐름을 확인합니다.

# %% [markdown]
# ## with 문 기초
#
# *자동 리소스 관리*

# %% [markdown]
# ## 컨텍스트 매니저 프로토콜
#
# *__enter__와 __exit__*

# %% [markdown]
# ## 리소스 관리
#
# *파일과 연결 관리*

# %% [markdown]
# ## 예외 처리
#
# *컨텍스트 매니저와 예외*

# %% [markdown]
# ## 다중 컨텍스트
#
# *여러 컨텍스트 매니저 사용*

# %% [markdown]
# ## 실전 패턴
#
# *컨텍스트 매니저 활용*

# %% [markdown]
# ## 현업 흐름 검증: 리포트 파일을 안전하게 쓰고 복원하기
#
# *예측 → 리소스 열기 → 오류 처리 → 정리 검증*

# %% [markdown]
# ## Day 28 종합 복습
#
# *컨텍스트 매니저 마스터하기*

# %% [markdown]
# ## 완료 기준
#
# - with 문이 자원 정리에 유리한 이유를 설명할 수 있다.
# - 직접 만든 컨텍스트 매니저의 시작과 종료 흐름을 말할 수 있다.
# - 예외가 있어도 정리 단계가 실행되는지 확인할 수 있다.
#
# ## 흔한 막힘
#
# - __exit__ 매개변수 개수를 틀림
# - with 블록 밖과 안의 실행 순서를 혼동함
# - 컨텍스트 매니저를 모든 코드 구조에 남용함
#
# ## 마무리
#
# 오늘 노트북에서 직접 작성한 연습 셀을 다시 훑어보세요. 설명을 보지 않고 같은 코드를 한 번 더 쓸 수 있으면 다음 Day로 넘어갑니다.
